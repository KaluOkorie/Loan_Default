# %% [markdown]
# # Importing Relevant Libraries

# %%
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Loading the Dataset

# %%
df = pd.read_csv('SouthGermanCredit.asc', sep=r'\s+')

# %%
# Read the file
df = pd.read_csv('SouthGermanCredit.asc', sep=r'\s+')

# Translate column names to English
german_to_english = {
    'laufkont': 'checking_account_status',
    'laufzeit': 'loan_duration_months',
    'moral': 'credit_history',
    'verw': 'purpose',
    'hoehe': 'credit_amount',
    'sparkont': 'savings_account_status',
    'beszeit': 'employment_duration',
    'rate': 'installment_rate',
    'famges': 'personal_status_sex',
    'buerge': 'guarantor',
    'wohnzeit': 'current_residence_duration',
    'verm': 'property',
    'alter': 'age',
    'weitkred': 'other_installment_plans',
    'wohn': 'housing',
    'bishkred': 'existing_credits_count',
    'beruf': 'job',
    'pers': 'dependents_count',
    'telef': 'telephone',
    'gastarb': 'foreign_worker',
    'kredit': 'credit_status'  
}
df.rename(columns=german_to_english, inplace=True)

# %%
df.shape
# Out:
# (1000, 21)

# %% [markdown]
# # Exploratory Data Analysis (EDA) and Preprocessing

# %%
# Columns to KEEP (adjust names to match your dataset)
columns_to_keep = [
    'age', 
    'credit_amount', 
    'employment_duration', 
    'credit_history', 
    'credit_status'  # Keep target variable if needed
]

# Drop all other columns
df = df[columns_to_keep]

# %%
df.shape
# Out:
# (1000, 5)

# %%
# Split data into features (X) and target (y)
X = df.drop('credit_status', axis=1)  # Only 4 features now
y = df['credit_status']

# %%
# Split the data (70% for training and 30% for testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Create a Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Make predictions on the test set
y_pred = rf_model.predict(X_test)

# %%
# Make predictions on the test set
y_pred = rf_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Print the evaluation metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.6500
# Precision: 0.7249
# Recall: 0.7981
# F1 Score: 0.7597

# %% [markdown]
# ## Save the model:

# %%
import joblib
# Load the retrained 4-feature model
model = joblib.load('4_feature_model.pkl')

# Now check feature names
print(model.feature_names_in_)
# Out:
# ['age' 'credit_amount' 'employment_duration' 'credit_history']
